# %% [markdown]
# <a href="https://colab.research.google.com/github/songqsh/18ma573pub/blob/master/src/pandas_basics_v01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# __Abstract__
#
# - Goal: Learn Pandas dataframe via an example
# - Ref:
#  https://github.com/pandas-dev/pandas

# %% [markdown]
# __Problem__
#
# - Import quandl stock data into dataframe
# - Manipulate dataframe, draw its 60 days rolling mean

# %%
# !pip install quandl #add this line if you run on colab
import quandl
import matplotlib.pyplot as plt
import pandas as pd

# %%
t0 = "2017-05-15" #start-date
t1 = "2018-05-15" #end-date
i_ticker = 'WIKI/INTC' #We import data from Wiki Table of Quandl
stk = quandl.get(i_ticker, start_date= t0, end_date=t1)

type(stk)
stk.head()
# Out:
#               Open     High    Low   Close      Volume  Ex-Dividend  \
# Date
# 2017-05-15  35.535  35.7150  35.42  35.630  21650268.0          0.0
# 2017-05-16  35.750  35.8900  35.42  35.820  22126165.0          0.0
# 2017-05-17  35.670  35.9896  35.02  35.040  25742251.0          0.0
# 2017-05-18  35.190  35.4700  35.08  35.220  16553907.0          0.0
# 2017-05-19  35.150  35.5500  35.13  35.385  17963279.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2017-05-15          1.0  34.862330  35.038922  34.749506   34.955531
# 2017-05-16          1.0  35.073260  35.210609  34.749506   35.141935
# 2017-05-17          1.0  34.994774  35.308324  34.357078   34.376700
# 2017-05-18          1.0  34.523860  34.798560  34.415943   34.553292
# 2017-05-19          1.0  34.484618  34.877046  34.464996   34.715169
#
#             Adj. Volume
# Date
# 2017-05-15   21650268.0
# 2017-05-16   22126165.0
# 2017-05-17   25742251.0
# 2017-05-18   16553907.0
# 2017-05-19   17963279.0

# %%
stk.Close.plot()
#stk.Volume.plot()

plt.title(i_ticker + " Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend();

plt.show()

# %%
rolling_mean = stk['Close'].rolling(10).mean()
stk.Close.plot()
rolling_mean.plot()


plt.title(i_ticker + ' Price with its rolling means')
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend();
plt.show()
